# %% [markdown]
# Módulo 23 - Compilacao de modelos I - Tarefa 02

# %% [markdown]
# 1.Passo a passo do Random Forest
# Começa com o dataset original.
# Aplica bootstrap nas linhas (amostragem com reposição).
# Seleciona colunas aleatórias (features) em cada amostra.
# Treina uma árvore de decisão para cada subconjunto.
# Repete isso várias vezes (várias árvores).
# Faz previsões com todas as árvores.
# Faz a agregação:
# classificação → voto da maioria
# regressão → média

# %% [markdown]
# 2.Explicação com minhas palavras
#
# Random Forest é uma evolução do Bagging que cria várias árvores de decisão usando dados diferentes e também variáveis diferentes, deixando os modelos mais independentes. Isso melhora a performance e reduz overfitting, porque as árvores ficam menos correlacionadas entre si.

# %% [markdown]
# 3.Código

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X, y = load_iris(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

modelo = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

modelo.fit(X_train, y_train)

y_pred = modelo.predict(X_test)

print("Acurácia:", accuracy_score(y_test, y_pred))
# Out:
# Acurácia: 1.0
